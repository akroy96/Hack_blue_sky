# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from tqdm import tqdm_notebook
from itertools import product

import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('AirQuality.csv',sep=";",parse_dates=[['Date', 'Time']],decimal=',',na_values=-200,na_filter=True)
data.drop(["Unnamed: 15","Unnamed: 16"],axis = 1,inplace = True)
data.head()
# Out:
#              Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004 18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004 19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004 20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004 21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004 22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date_Time      9471 non-null   object
#  1   CO(GT)         7674 non-null   float64
#  2   PT08.S1(CO)    8991 non-null   float64
#  3   NMHC(GT)       914 non-null    float64
#  4   C6H6(GT)       8991 non-null   float64
#  5   PT08.S2(NMHC)  8991 non-null   float64
#  6   NOx(GT)        7718 non-null   float64
#  7   PT08.S3(NOx)   8991 non-null   float64
#  8   NO2(GT)        7715 non-null   float64
#  9   PT08.S4(NO2)   8991 non-null   float64
#  10  PT08.S5(O3)    8991 non-null   float64
#  11  T              8991 non-null   float64
#  12  RH             8991 non-null   float64
#  13  AH             8991 non-null   float64
# dtypes: float64(13), object(1)
# memory usage: 1.0+ MB

# %%
data.tail()
# Out:
#      Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 9466   nan nan     NaN          NaN       NaN       NaN            NaN
# 9467   nan nan     NaN          NaN       NaN       NaN            NaN
# 9468   nan nan     NaN          NaN       NaN       NaN            NaN
# 9469   nan nan     NaN          NaN       NaN       NaN            NaN
# 9470   nan nan     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH
# 9466      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9467      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9468      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9469      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9470      NaN           NaN      NaN           NaN          NaN NaN NaN NaN

# %%
data.fillna(method='ffill',inplace=True)
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (9358, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9358 entries, 0 to 9357
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date_Time      9358 non-null   object
#  1   CO(GT)         9358 non-null   float64
#  2   PT08.S1(CO)    9358 non-null   float64
#  3   NMHC(GT)       9358 non-null   float64
#  4   C6H6(GT)       9358 non-null   float64
#  5   PT08.S2(NMHC)  9358 non-null   float64
#  6   NOx(GT)        9358 non-null   float64
#  7   PT08.S3(NOx)   9358 non-null   float64
#  8   NO2(GT)        9358 non-null   float64
#  9   PT08.S4(NO2)   9358 non-null   float64
#  10  PT08.S5(O3)    9358 non-null   float64
#  11  T              9358 non-null   float64
#  12  RH             9358 non-null   float64
#  13  AH             9358 non-null   float64
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
data.tail()
# Out:
#                 Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9353  04/04/2005 11.00.00     2.4       1163.0     275.0      11.4
# 9354  04/04/2005 12.00.00     2.4       1142.0     275.0      12.4
# 9355  04/04/2005 13.00.00     2.1       1003.0     275.0       9.5
# 9356  04/04/2005 14.00.00     2.2       1071.0     275.0      11.9
# 9357              nan nan     2.2       1071.0     275.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
# 9357         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# 9355        770.0  28.3  13.5  0.5139
# 9356        816.0  28.5  13.1  0.5028
# 9357        816.0  28.5  13.1  0.5028

# %%
data.drop(9357,inplace = True)
data.tail()
# Out:
#                 Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005 10.00.00     3.1       1314.0     275.0      13.5
# 9353  04/04/2005 11.00.00     2.4       1163.0     275.0      11.4
# 9354  04/04/2005 12.00.00     2.4       1142.0     275.0      12.4
# 9355  04/04/2005 13.00.00     2.1       1003.0     275.0       9.5
# 9356  04/04/2005 14.00.00     2.2       1071.0     275.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# 9355        770.0  28.3  13.5  0.5139
# 9356        816.0  28.5  13.1  0.5028

# %%
data['Date_Time'] = pd.to_datetime(data['Date_Time'],format="%d/%m/%Y %H.%M.%S")

# %%
d_r = data.set_index('Date_Time')
# d_r = data

# %%
d_r.tail()
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2005-04-04 10:00:00     3.1       1314.0     275.0      13.5         1101.0
# 2005-04-04 11:00:00     2.4       1163.0     275.0      11.4         1027.0
# 2005-04-04 12:00:00     2.4       1142.0     275.0      12.4         1063.0
# 2005-04-04 13:00:00     2.1       1003.0     275.0       9.5          961.0
# 2005-04-04 14:00:00     2.2       1071.0     275.0      11.9         1047.0
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Date_Time
# 2005-04-04 10:00:00    472.0         539.0    190.0        1374.0
# 2005-04-04 11:00:00    353.0         604.0    179.0        1264.0
# 2005-04-04 12:00:00    293.0         603.0    175.0        1241.0
# 2005-04-04 13:00:00    235.0         702.0    156.0        1041.0
# 2005-04-04 14:00:00    265.0         654.0    168.0        1129.0
#
#                      PT08.S5(O3)     T    RH      AH
# Date_Time
# 2005-04-04 10:00:00       1729.0  21.9  29.3  0.7568
# 2005-04-04 11:00:00       1269.0  24.3  23.7  0.7119
# 2005-04-04 12:00:00       1092.0  26.9  18.3  0.6406
# 2005-04-04 13:00:00        770.0  28.3  13.5  0.5139
# 2005-04-04 14:00:00        816.0  28.5  13.1  0.5028

# %%
d_r[['CO(GT)','T']].plot(subplots=True, figsize=(10,6))
# Out:
# array([<AxesSubplot:xlabel='Date_Time'>, <AxesSubplot:xlabel='Date_Time'>],
#       dtype=object)

# %%
print(f'min : {data["Date_Time"].min()} max : {data["Date_Time"].max()}')
print(f'difference of min max : {data["Date_Time"].iloc[-1] - data["Date_Time"].iloc[0]}')#pd.to_datetime(data["Date_Time"].iloc[-1]) - pd.to_datetime(data["Date_Time"].iloc[0])}')
# Out:
# min : 2004-03-10 18:00:00 max : 2005-04-04 14:00:00
# difference of min max : 389 days 20:00:00

# %% [markdown]
# ```python
# macro_data = d_r
# fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(10,13),squeeze=True)
# for i, ax in enumerate(axes.flatten()):
# #     if i == 0 or i == 11:
# #     if i == 0 :
# #         pass
#     data = macro_data[macro_data.columns[i]]
# #         print(data)
# #     ax.plot(macro_data['Date_Time'],data, color='lightblue')#, linewidth=1)
#     ax.plot(data,color='red')
#     # Decorations
#     ax.set_title(macro_data.columns[i])
#     ax.xaxis.set_ticks_position('none')
#     ax.yaxis.set_ticks_position('none')
#     ax.spines["top"].set_alpha(0)
#     ax.tick_params(labelsize=6)
#
# plt.tight_layout();
# ```

# %%
ad_fuller_result_1 = adfuller(macro_data['CO(GT)'].diff()[1:])

print('realgdp')
print(f'ADF Statistic: {ad_fuller_result_1[0]}')
print(f'p-value: {ad_fuller_result_1[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(macro_data['T'].diff()[1:])

print('realcons')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8ce66584f00b> in <module>
# ----> 1 ad_fuller_result_1 = adfuller(macro_data['CO(GT)'].diff()[1:])
#       2
#       3 print('realgdp')
#       4 print(f'ADF Statistic: {ad_fuller_result_1[0]}')
#       5 print(f'p-value: {ad_fuller_result_1[1]}')
#
# NameError: name 'macro_data' is not defined

# %%
print('CO(GT) causes T?\n')
print('------------------')
granger_1 = grangercausalitytests(macro_data[['T', 'CO(GT)']], 4)

print('\nT causes CO(GT)?\n')
print('------------------')
granger_2 = grangercausalitytests(macro_data[['CO(GT)', 'T']], 4)
# Out:
# CO(GT) causes T?
#
# ------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f50c5eedac58> in <module>
#       1 print('CO(GT) causes T?\n')
#       2 print('------------------')
# ----> 3 granger_1 = grangercausalitytests(macro_data[['T', 'CO(GT)']], 4)
#       4
#       5 print('\nT causes CO(GT)?\n')
#
# NameError: name 'macro_data' is not defined

# %% [markdown]
# ## ToDo
# #### preprocessing
#
# * chose edge padding
#
# ~~+ wavelet transform~~
#
# ~~+ discrete cosine transform~~
#
# #### training length
# temporary
# + past 4 days [96 input points 24 output points]
# + past 3 days [72 input points 24 output points]
# + past 2 days [48 input points 24 output points]
# + past 1 days [24 input points 24 output points]
#
#
# #### modeling
# + SARIMA
# + Bidirectional LSTM's
#
# ~~+ XGBoost~~
#
# Remember : should implement online leanring technique
#
# Note : Yes, the participants need to use temperature data independently to evaluate their algorithm. Dont use temperature data to forecast CO and vice versa.
#
# Initial Training Data Period: 7 days from 11/03/2004 00.00.00 to 17/03/2004 23.00.00 ✅
#
# Testing Data Period: 7 days from 18/03/2004 00.00.00 to 24/03/2004 23.00.00 ✅
#
# Each day of the training and test data period have 24 data points starting from 00.00.00 to 23.00.00. ✅
#
# Understanding :
# outof all the samples take only those 2 sets..
#
# according to it each day is having 24 points (Check it) ✅
#
# follow up the procedure given ..
#
# Question: so how many samples in a day should be predicted i.e. output should be a float or list ??
#
# can be found out in eda..
#
# ### Re-Training on Test Data is not necessary.

# %%
data[data['Date_Time'] == pd.to_datetime('11/03/2004 00.00.0',format="%d/%m/%Y %H.%M.%S")]
# Out:
#    Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 6 2004-03-11     1.2       1185.0      31.0       3.6          690.0     62.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 6        1462.0     77.0        1333.0        733.0  11.3  56.8  0.7603

# %%
data.iloc[6:6+7]
# Out:
#              Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 6  2004-03-11 00:00:00     1.2       1185.0      31.0       3.6
# 7  2004-03-11 01:00:00     1.0       1136.0      31.0       3.3
# 8  2004-03-11 02:00:00     0.9       1094.0      24.0       2.3
# 9  2004-03-11 03:00:00     0.6       1010.0      19.0       1.7
# 10 2004-03-11 04:00:00     0.6       1011.0      14.0       1.3
# 11 2004-03-11 05:00:00     0.7       1066.0       8.0       1.1
# 12 2004-03-11 06:00:00     0.7       1052.0      16.0       1.6
#
#     PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 6           690.0     62.0        1462.0     77.0        1333.0        733.0
# 7           672.0     62.0        1453.0     76.0        1333.0        730.0
# 8           609.0     45.0        1579.0     60.0        1276.0        620.0
# 9           561.0     45.0        1705.0     60.0        1235.0        501.0
# 10          527.0     21.0        1818.0     34.0        1197.0        445.0
# 11          512.0     16.0        1918.0     28.0        1182.0        422.0
# 12          553.0     34.0        1738.0     48.0        1221.0        472.0
#
#        T    RH      AH
# 6   11.3  56.8  0.7603
# 7   10.7  60.0  0.7702
# 8   10.7  59.7  0.7648
# 9   10.3  60.2  0.7517
# 10  10.1  60.5  0.7465
# 11  11.0  56.2  0.7366
# 12  10.5  58.1  0.7353

# %%
d_r.iloc[6:6+168]
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2004-03-11 00:00:00     1.2       1185.0      31.0       3.6          690.0
# 2004-03-11 01:00:00     1.0       1136.0      31.0       3.3          672.0
# 2004-03-11 02:00:00     0.9       1094.0      24.0       2.3          609.0
# 2004-03-11 03:00:00     0.6       1010.0      19.0       1.7          561.0
# 2004-03-11 04:00:00     0.6       1011.0      14.0       1.3          527.0
# ...                     ...          ...       ...       ...            ...
# 2004-03-17 19:00:00     7.6       1973.0     577.0      38.4         1737.0
# 2004-03-17 20:00:00     6.7       1975.0     523.0      35.1         1667.0
# 2004-03-17 21:00:00     5.7       1795.0     472.0      27.2         1485.0
# 2004-03-17 22:00:00     2.8       1444.0     206.0      15.0         1150.0
# 2004-03-17 23:00:00     2.6       1488.0     216.0      15.7         1171.0
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Date_Time
# 2004-03-11 00:00:00     62.0        1462.0     77.0        1333.0
# 2004-03-11 01:00:00     62.0        1453.0     76.0        1333.0
# 2004-03-11 02:00:00     45.0        1579.0     60.0        1276.0
# 2004-03-11 03:00:00     45.0        1705.0     60.0        1235.0
# 2004-03-11 04:00:00     21.0        1818.0     34.0        1197.0
# ...                      ...           ...      ...           ...
# 2004-03-17 19:00:00    411.0         617.0    194.0        2414.0
# 2004-03-17 20:00:00    347.0         597.0    182.0        2416.0
# 2004-03-17 21:00:00    336.0         653.0    180.0        2174.0
# 2004-03-17 22:00:00    202.0         770.0    136.0        1727.0
# 2004-03-17 23:00:00    178.0         731.0    127.0        1778.0
#
#                      PT08.S5(O3)     T    RH      AH
# Date_Time
# 2004-03-11 00:00:00        733.0  11.3  56.8  0.7603
# 2004-03-11 01:00:00        730.0  10.7  60.0  0.7702
# 2004-03-11 02:00:00        620.0  10.7  59.7  0.7648
# 2004-03-11 03:00:00        501.0  10.3  60.2  0.7517
# 2004-03-11 04:00:00        445.0  10.1  60.5  0.7465
# ...                          ...   ...   ...     ...
# 2004-03-17 19:00:00       2306.0  23.1  26.5  0.7403
# 2004-03-17 20:00:00       2359.0  20.5  38.2  0.9133
# 2004-03-17 21:00:00       2050.0  19.1  42.6  0.9294
# 2004-03-17 22:00:00       1727.0  17.2  44.1  0.8558
# 2004-03-17 23:00:00       1705.0  16.0  50.9  0.9206
#
# [168 rows x 13 columns]

# %%
d_r[['CO(GT)','T']].iloc[6:6+168].plot(subplots=True, figsize=(10,6))
# Out:
# array([<AxesSubplot:xlabel='Date_Time'>, <AxesSubplot:xlabel='Date_Time'>],
#       dtype=object)

# %%
d_r[['CO(GT)','T']].iloc[6+168:6+2*168]
# Out:
#                      CO(GT)     T
# Date_Time
# 2004-03-18 00:00:00     2.3  14.8
# 2004-03-18 01:00:00     1.4  14.3
# 2004-03-18 02:00:00     1.0  14.8
# 2004-03-18 03:00:00     0.7  13.9
# 2004-03-18 04:00:00     0.7  11.6
# ...                     ...   ...
# 2004-03-24 19:00:00     4.5  10.7
# 2004-03-24 20:00:00     3.5  10.8
# 2004-03-24 21:00:00     2.6  10.3
# 2004-03-24 22:00:00     1.7  10.1
# 2004-03-24 23:00:00     1.3  10.4
#
# [168 rows x 2 columns]

# %%
d_r[['CO(GT)','T']].iloc[6+168:6+2*168].plot(subplots=True, figsize=(10,6))
# Out:
# array([<AxesSubplot:xlabel='Date_Time'>, <AxesSubplot:xlabel='Date_Time'>],
#       dtype=object)

# %%
d_r[['CO(GT)','T']].iloc[6:6+2*168].plot(subplots=True, figsize=(20,6))
# Out:
# array([<AxesSubplot:xlabel='Date_Time'>, <AxesSubplot:xlabel='Date_Time'>],
#       dtype=object)

# %%
train_data = d_r[['CO(GT)','T']].iloc[6:6+168]
test_data = d_r[['CO(GT)','T']].iloc[6+168:6+2*168]

# %%
test_np = train_data['T'].to_numpy()

# %%
for i in range(2*150):
    try : 
        print(f'train : {test_np[i:i+72]} test : {test_np[i+72:i+72+24]} i : {i} len of test : {len(test_np[i+72:i+72+24])}')
    except :
        print(f'exception got at : {i}')
# Out:
# train : [11.3 10.7 10.7 10.3 10.1 11.  10.5 10.2 10.8 10.5 10.8 10.5  9.5  8.3
#   8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.
#   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9
#  15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3
#   6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3
#  14.6 14.7] test : [13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2
#  21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7] i : 0 len of test : 24
# train : [10.7 10.7 10.3 10.1 11.  10.5 10.2 10.8 10.5 10.8 10.5  9.5  8.3  8.
#   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1
#   6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1
#  14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5
#   9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6
#  14.7 13.9] test : [14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4
#  21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8] i : 1 len of test : 24
# train : [10.7 10.3 10.1 11.  10.5 10.2 10.8 10.5 10.8 10.5  9.5  8.3  8.   8.3
#   9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3
#   6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4
#  12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6
#  12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7
#  13.9 14.6] test : [12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9
#  22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14. ] i : 2 len of test : 24
# train : [10.3 10.1 11.  10.5 10.2 10.8 10.5 10.8 10.5  9.5  8.3  8.   8.3  9.7
#   9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8
#   6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9
#  12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4
#  15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9
#  14.6 12.5] test : [11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2
#  21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4] i : 3 len of test : 24
# train : [10.1 11.  10.5 10.2 10.8 10.5 10.8 10.5  9.5  8.3  8.   8.3  9.7  9.8
#  10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4
#   7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1
#  11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6
#  18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6
#  12.5 11.6] test : [12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3
#  19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6] i : 4 len of test : 24
# train : [11.  10.5 10.2 10.8 10.5 10.8 10.5  9.5  8.3  8.   8.3  9.7  9.8 10.3
#   9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3
#   9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.
#   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4
#  19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5
#  11.6 12.1] test : [11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7
#  18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3] i : 5 len of test : 24
# train : [10.5 10.2 10.8 10.5 10.8 10.5  9.5  8.3  8.   8.3  9.7  9.8 10.3  9.7
#   9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2
#  13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7
#   9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4
#  18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6
#  12.1 11.5] test : [11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4
#  17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9] i : 6 len of test : 24
# train : [10.2 10.8 10.5 10.8 10.5  9.5  8.3  8.   8.3  9.7  9.8 10.3  9.7  9.6
#   9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2
#  14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5
#   9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.
#  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1
#  11.5 11.6] test : [10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6
#  16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4] i : 7 len of test : 24
# train : [10.8 10.5 10.8 10.5  9.5  8.3  8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1
#   8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3
#  15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1
#   8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4
#  17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5
#  11.6 10.4] test : [11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7
#  16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3] i : 8 len of test : 24
# train : [10.5 10.8 10.5  9.5  8.3  8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2
#   8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.
#  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8
#   7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6
#  16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6
#  10.4 11.6] test : [12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3
#  14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4] i : 9 len of test : 24
# train : [10.8 10.5  9.5  8.3  8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2
#   8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1
#  16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8
#   7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7
#  16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4
#  11.6 12.4] test : [14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7
#  14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8] i : 10 len of test : 24
# train : [10.5  9.5  8.3  8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3
#   7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3
#  15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.
#   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1
#  15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6
#  12.4 14.5] test : [16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8
#  14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4] i : 11 len of test : 24
# train : [ 9.5  8.3  8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7
#   7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8
#  15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3
#   7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8
#  15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4
#  14.5 16.9] test : [19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.
#  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8] i : 12 len of test : 24
# train : [ 8.3  8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1
#   7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9
#  16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2
#   6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7
#  15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5
#  16.9 19.3] test : [21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4
#  12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22. ] i : 13 len of test : 24
# train : [ 8.   8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.
#   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9
#  15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3
#   6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3
#  14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9
#  19.3 21.2] test : [21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6
#  12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3] i : 14 len of test : 24
# train : [ 8.3  9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1
#   6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1
#  14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5
#   9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6
#  14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3
#  21.2 21.4] test : [21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3
#  11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9] i : 15 len of test : 24
# train : [ 9.7  9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3
#   6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4
#  12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6
#  12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7
#  13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2
#  21.4 21.9] test : [22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9
#  11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4] i : 16 len of test : 24
# train : [ 9.8 10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8
#   6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9
#  12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4
#  15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9
#  14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4
#  21.9 22.2] test : [21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4
#  11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4] i : 17 len of test : 24
# train : [10.3  9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4
#   7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1
#  11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6
#  18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6
#  12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9
#  22.2 21.3] test : [19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3
#  12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8] i : 18 len of test : 24
# train : [ 9.7  9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3
#   9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.
#   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4
#  19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5
#  11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2
#  21.3 19.7] test : [18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4
#  14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5] i : 19 len of test : 24
# train : [ 9.6  9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2
#  13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7
#   9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4
#  18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6
#  12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3
#  19.7 18.4] test : [17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8
#  17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4] i : 20 len of test : 24
# train : [ 9.1  8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2
#  14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5
#   9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.
#  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1
#  11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7
#  18.4 17.6] test : [16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4
#  19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3] i : 21 len of test : 24
# train : [ 8.2  8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3
#  15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1
#   8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4
#  17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5
#  11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4
#  17.6 16.7] test : [16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8
#  22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7] i : 22 len of test : 24
# train : [ 8.2  8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.
#  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8
#   7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6
#  16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6
#  10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6
#  16.7 16.3] test : [14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.
#  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7] i : 23 len of test : 24
# train : [ 8.3  7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1
#  16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8
#   7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7
#  16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4
#  11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7
#  16.3 14.7] test : [14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3
#  23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3] i : 24 len of test : 24
# train : [ 7.7  7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3
#  15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.
#   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1
#  15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6
#  12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3
#  14.7 14.8] test : [14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9
#  24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1] i : 25 len of test : 24
# train : [ 7.1  7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8
#  15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3
#   7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8
#  15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4
#  14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7
#  14.8 14. ] test : [13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4
#  24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8] i : 26 len of test : 24
# train : [ 7.   6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9
#  16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2
#   6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7
#  15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5
#  16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8
#  14.  13.4] test : [12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4
#  23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8] i : 27 len of test : 24
# train : [ 6.1  6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9
#  15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3
#   6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3
#  14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9
#  19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.
#  13.4 12.6] test : [12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8
#  22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6] i : 28 len of test : 24
# train : [ 6.3  6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1
#  14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5
#   9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6
#  14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3
#  21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4
#  12.6 12.3] test : [11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5
#  20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3] i : 29 len of test : 24
# train : [ 6.8  6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4
#  12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6
#  12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7
#  13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2
#  21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6
#  12.3 11.9] test : [11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4
#  18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8] i : 30 len of test : 24
# train : [ 6.4  7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9
#  12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4
#  15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9
#  14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4
#  21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3
#  11.9 11.4] test : [11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3
#  16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2] i : 31 len of test : 24
# train : [ 7.3  9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1
#  11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6
#  18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6
#  12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9
#  22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9
#  11.4 11.3] test : [12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7
#  15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11. ] i : 32 len of test : 24
# train : [ 9.2 13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.
#   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4
#  19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5
#  11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2
#  21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4
#  11.3 12.4] test : [14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7
#  15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7] i : 33 len of test : 24
# train : [13.2 14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7
#   9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4
#  18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6
#  12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3
#  19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3
#  12.4 14.8] test : [17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3
#  14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6] i : 34 len of test : 24
# train : [14.3 15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5
#   9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.
#  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1
#  11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7
#  18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4
#  14.8 17.4] test : [19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1
#  14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8] i : 35 len of test : 24
# train : [15.  16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1
#   8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4
#  17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5
#  11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4
#  17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8
#  17.4 19.8] test : [22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8
#  14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4] i : 36 len of test : 24
# train : [16.1 16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8
#   7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6
#  16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6
#  10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6
#  16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4
#  19.8 22. ] test : [23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8
#  13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4] i : 37 len of test : 24
# train : [16.3 15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8
#   7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7
#  16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4
#  11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7
#  16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8
#  22.  23.3] test : [23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6
#  12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3] i : 38 len of test : 24
# train : [15.8 15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.
#   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1
#  15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6
#  12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3
#  14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.
#  23.3 23.9] test : [24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3
#  12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8] i : 39 len of test : 24
# train : [15.9 16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3
#   7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8
#  15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4
#  14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7
#  14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3
#  23.9 24.4] test : [24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8
#  11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27. ] i : 40 len of test : 24
# train : [16.9 15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2
#   6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7
#  15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5
#  16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8
#  14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9
#  24.4 24.4] test : [23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2
#  11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2] i : 41 len of test : 24
# train : [15.1 14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3
#   6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3
#  14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9
#  19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.
#  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4
#  24.4 23.8] test : [22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.
#  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28. ] i : 42 len of test : 24
# train : [14.4 12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5
#   9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6
#  14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3
#  21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4
#  12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4
#  23.8 22.5] test : [20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7
#  13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9] i : 43 len of test : 24
# train : [12.9 12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6
#  12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7
#  13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2
#  21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6
#  12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8
#  22.5 20.4] test : [18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6
#  17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3] i : 44 len of test : 24
# train : [12.1 11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4
#  15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9
#  14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4
#  21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3
#  11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5
#  20.4 18.3] test : [16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8
#  21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4] i : 45 len of test : 24
# train : [11.   9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6
#  18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6
#  12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9
#  22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9
#  11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4
#  18.3 16.7] test : [15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4
#  24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19. ] i : 46 len of test : 24
# train : [ 9.7  9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4
#  19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5
#  11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2
#  21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4
#  11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3
#  16.7 15.7] test : [15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4
#  25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9] i : 47 len of test : 24
# train : [ 9.5  9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4
#  18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6
#  12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3
#  19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3
#  12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7
#  15.7 15.3] test : [14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3
#  25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7] i : 48 len of test : 24
# train : [ 9.1  8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.
#  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1
#  11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7
#  18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4
#  14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7
#  15.3 14.1] test : [14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8
#  27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5] i : 49 len of test : 24
# train : [ 8.8  7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4
#  17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5
#  11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4
#  17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8
#  17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3
#  14.1 14.8] test : [14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.
#  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5] i : 50 len of test : 24
# train : [ 7.8  7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6
#  16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6
#  10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6
#  16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4
#  19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1
#  14.8 14.8] test : [13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2
#  28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1] i : 51 len of test : 24
# train : [ 7.   8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7
#  16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4
#  11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7
#  16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8
#  22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8
#  14.8 13.6] test : [12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.
#  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1] i : 52 len of test : 24
# train : [ 8.3  7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1
#  15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6
#  12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3
#  14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.
#  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8
#  13.6 12.3] test : [12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9
#  21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7] i : 53 len of test : 24
# train : [ 7.2  6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8
#  15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4
#  14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7
#  14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3
#  23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6
#  12.3 12.8] test : [11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3
#  20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8] i : 54 len of test : 24
# train : [ 6.3  6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7
#  15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5
#  16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8
#  14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9
#  24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3
#  12.8 11.2] test : [11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4
#  19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9] i : 55 len of test : 24
# train : [ 6.5  9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3
#  14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9
#  19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.
#  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4
#  24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8
#  11.2 11. ] test : [11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.
#  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9] i : 56 len of test : 24
# train : [ 9.6 12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6
#  14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3
#  21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4
#  12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4
#  23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2
#  11.  11.7] test : [13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9
#  16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1] i : 57 len of test : 24
# train : [12.4 15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7
#  13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2
#  21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6
#  12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8
#  22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.
#  11.7 13.6] test : [17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7
#  15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1] i : 58 len of test : 24
# train : [15.6 18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9
#  14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4
#  21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3
#  11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5
#  20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7
#  13.6 17.8] test : [21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5
#  15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7] i : 59 len of test : 24
# train : [18.4 19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6
#  12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9
#  22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9
#  11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4
#  18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6
#  17.8 21.4] test : [24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5
#  14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1] i : 60 len of test : 24
# train : [19.4 18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5
#  11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2
#  21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4
#  11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3
#  16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8
#  21.4 24.4] test : [25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1
#  13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3] i : 61 len of test : 24
# train : [18.  18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6
#  12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3
#  19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3
#  12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7
#  15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4
#  24.4 25.3] test : [25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1
#  12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6] i : 62 len of test : 24
# train : [18.4 17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1
#  11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7
#  18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4
#  14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7
#  15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4
#  25.3 25.8] test : [27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7
#  11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9] i : 63 len of test : 24
# train : [17.6 16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5
#  11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4
#  17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8
#  17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3
#  14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3
#  25.8 27. ] test : [28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8
#  11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8] i : 64 len of test : 24
# train : [16.7 16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6
#  10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6
#  16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4
#  19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1
#  14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8
#  27.  28.2] test : [28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9
#   9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3] i : 65 len of test : 24
# train : [16.1 15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4
#  11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7
#  16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8
#  22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8
#  14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.
#  28.2 28. ] test : [23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9
#  11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5] i : 66 len of test : 24
# train : [15.8 15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6
#  12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3
#  14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.
#  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8
#  13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2
#  28.  23.9] test : [21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1
#  14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9] i : 67 len of test : 24
# train : [15.7 15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4
#  14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7
#  14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3
#  23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6
#  12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.
#  23.9 21.3] test : [20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1
#  17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1] i : 68 len of test : 24
# train : [15.3 14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5
#  16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8
#  14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9
#  24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3
#  12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9
#  21.3 20.4] test : [19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7
#  21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5] i : 69 len of test : 24
# train : [14.6 14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9
#  19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.
#  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4
#  24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8
#  11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3
#  20.4 19. ] test : [17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1
#  24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1] i : 70 len of test : 24
# train : [14.7 13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3
#  21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4
#  12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4
#  23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2
#  11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4
#  19.  17.9] test : [16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3
#  25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2] i : 71 len of test : 24
# train : [13.9 14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2
#  21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6
#  12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8
#  22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.
#  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.
#  17.9 16.7] test : [15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6
#  25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 72 len of test : 24
# train : [14.6 12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4
#  21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3
#  11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5
#  20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7
#  13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9
#  16.7 15.5] test : [15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9
#  26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 73 len of test : 23
# train : [12.5 11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9
#  22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9
#  11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4
#  18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6
#  17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7
#  15.5 15.5] test : [14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8
#  29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 74 len of test : 22
# train : [11.6 12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2
#  21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4
#  11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3
#  16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8
#  21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5
#  15.5 14.1] test : [13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3
#  28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 75 len of test : 21
# train : [12.1 11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3
#  19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3
#  12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7
#  15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4
#  24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5
#  14.1 13.1] test : [12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5
#  25.9 23.1 20.5 19.1 17.2 16. ] i : 76 len of test : 20
# train : [11.5 11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7
#  18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4
#  14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7
#  15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4
#  25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1
#  13.1 12.7] test : [11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9
#  23.1 20.5 19.1 17.2 16. ] i : 77 len of test : 19
# train : [11.6 10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4
#  17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8
#  17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3
#  14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3
#  25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1
#  12.7 11.8] test : [11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1
#  20.5 19.1 17.2 16. ] i : 78 len of test : 18
# train : [10.4 11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6
#  16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4
#  19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1
#  14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8
#  27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7
#  11.8 11.9] test : [ 9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5
#  19.1 17.2 16. ] i : 79 len of test : 17
# train : [11.6 12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7
#  16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8
#  22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8
#  14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.
#  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8
#  11.9  9.9] test : [11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1
#  17.2 16. ] i : 80 len of test : 16
# train : [12.4 14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3
#  14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.
#  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8
#  13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2
#  28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9
#   9.9 11.1] test : [14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2
#  16. ] i : 81 len of test : 15
# train : [14.5 16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7
#  14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3
#  23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6
#  12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.
#  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9
#  11.1 14.1] test : [17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 82 len of test : 14
# train : [16.9 19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8
#  14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9
#  24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3
#  12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9
#  21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1
#  14.1 17.7] test : [21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 83 len of test : 13
# train : [19.3 21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.
#  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4
#  24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8
#  11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3
#  20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1
#  17.7 21.1] test : [24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 84 len of test : 12
# train : [21.2 21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4
#  12.6 12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4
#  23.8 22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2
#  11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4
#  19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7
#  21.1 24.3] test : [25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 85 len of test : 11
# train : [21.4 21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6
#  12.3 11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8
#  22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.
#  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.
#  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1
#  24.3 25.6] test : [25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 86 len of test : 10
# train : [21.9 22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3
#  11.9 11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5
#  20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7
#  13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9
#  16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3
#  25.6 25.9] test : [26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 87 len of test : 9
# train : [22.2 21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9
#  11.4 11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4
#  18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6
#  17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7
#  15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6
#  25.9 26.8] test : [29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 88 len of test : 8
# train : [21.3 19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4
#  11.3 12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3
#  16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8
#  21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5
#  15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9
#  26.8 29.3] test : [28.5 25.9 23.1 20.5 19.1 17.2 16. ] i : 89 len of test : 7
# train : [19.7 18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3
#  12.4 14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7
#  15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4
#  24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5
#  14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8
#  29.3 28.5] test : [25.9 23.1 20.5 19.1 17.2 16. ] i : 90 len of test : 6
# train : [18.4 17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4
#  14.8 17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7
#  15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4
#  25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1
#  13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3
#  28.5 25.9] test : [23.1 20.5 19.1 17.2 16. ] i : 91 len of test : 5
# train : [17.6 16.7 16.3 14.7 14.8 14.  13.4 12.6 12.3 11.9 11.4 11.3 12.4 14.8
#  17.4 19.8 22.  23.3 23.9 24.4 24.4 23.8 22.5 20.4 18.3 16.7 15.7 15.3
#  14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3
#  25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1
# ...
#  19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7
#  21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 113 len of test : 0
# train : [22.5 20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.
#  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.
#  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1
#  24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 114 len of test : 0
# train : [20.4 18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7
#  13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9
#  16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3
#  25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 115 len of test : 0
# train : [18.3 16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6
#  17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7
#  15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6
#  25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 116 len of test : 0
# train : [16.7 15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8
#  21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5
#  15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9
#  26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 117 len of test : 0
# train : [15.7 15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4
#  24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5
#  14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8
#  29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 118 len of test : 0
# train : [15.3 14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4
#  25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1
#  13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3
#  28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 119 len of test : 0
# train : [14.1 14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3
#  25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1
#  12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5
#  25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 120 len of test : 0
# train : [14.8 14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8
#  27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7
#  11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9
#  23.1 20.5 19.1 17.2 16. ] test : [] i : 121 len of test : 0
# train : [14.8 13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.
#  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8
#  11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1
#  20.5 19.1 17.2 16. ] test : [] i : 122 len of test : 0
# train : [13.6 12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2
#  28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9
#   9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5
#  19.1 17.2 16. ] test : [] i : 123 len of test : 0
# train : [12.3 12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.
#  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9
#  11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1
#  17.2 16. ] test : [] i : 124 len of test : 0
# train : [12.8 11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9
#  21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1
#  14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2
#  16. ] test : [] i : 125 len of test : 0
# train : [11.2 11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3
#  20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1
#  17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 126 len of test : 0
# train : [11.  11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4
#  19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7
#  21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 127 len of test : 0
# train : [11.7 13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.
#  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1
#  24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 128 len of test : 0
# train : [13.6 17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9
#  16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3
#  25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 129 len of test : 0
# train : [17.8 21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7
#  15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6
#  25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 130 len of test : 0
# train : [21.4 24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5
#  15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9
#  26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 131 len of test : 0
# train : [24.4 25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5
#  14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8
#  29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 132 len of test : 0
# train : [25.3 25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1
#  13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3
#  28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 133 len of test : 0
# train : [25.8 27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1
#  12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5
#  25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 134 len of test : 0
# train : [27.  28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7
#  11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9
#  23.1 20.5 19.1 17.2 16. ] test : [] i : 135 len of test : 0
# train : [28.2 28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8
#  11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1
#  20.5 19.1 17.2 16. ] test : [] i : 136 len of test : 0
# train : [28.  23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9
#   9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5
#  19.1 17.2 16. ] test : [] i : 137 len of test : 0
# train : [23.9 21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9
#  11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1
#  17.2 16. ] test : [] i : 138 len of test : 0
# train : [21.3 20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1
#  14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2
#  16. ] test : [] i : 139 len of test : 0
# train : [20.4 19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1
#  17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 140 len of test : 0
# train : [19.  17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7
#  21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 141 len of test : 0
# train : [17.9 16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1
#  24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 142 len of test : 0
# train : [16.7 15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3
#  25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 143 len of test : 0
# train : [15.5 15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6
#  25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 144 len of test : 0
# train : [15.5 14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9
#  26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 145 len of test : 0
# train : [14.1 13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8
#  29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 146 len of test : 0
# train : [13.1 12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3
#  28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 147 len of test : 0
# train : [12.7 11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5
#  25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 148 len of test : 0
# train : [11.8 11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9
#  23.1 20.5 19.1 17.2 16. ] test : [] i : 149 len of test : 0
# train : [11.9  9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1
#  20.5 19.1 17.2 16. ] test : [] i : 150 len of test : 0
# train : [ 9.9 11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5
#  19.1 17.2 16. ] test : [] i : 151 len of test : 0
# train : [11.1 14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1
#  17.2 16. ] test : [] i : 152 len of test : 0
# train : [14.1 17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2
#  16. ] test : [] i : 153 len of test : 0
# train : [17.7 21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 154 len of test : 0
# train : [21.1 24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 155 len of test : 0
# train : [24.3 25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 156 len of test : 0
# train : [25.6 25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 157 len of test : 0
# train : [25.9 26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 158 len of test : 0
# train : [26.8 29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 159 len of test : 0
# train : [29.3 28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 160 len of test : 0
# train : [28.5 25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 161 len of test : 0
# train : [25.9 23.1 20.5 19.1 17.2 16. ] test : [] i : 162 len of test : 0
# train : [23.1 20.5 19.1 17.2 16. ] test : [] i : 163 len of test : 0
# train : [20.5 19.1 17.2 16. ] test : [] i : 164 len of test : 0
# train : [19.1 17.2 16. ] test : [] i : 165 len of test : 0
# train : [17.2 16. ] test : [] i : 166 len of test : 0
# train : [16.] test : [] i : 167 len of test : 0
# train : [] test : [] i : 168 len of test : 0
# train : [] test : [] i : 169 len of test : 0
# train : [] test : [] i : 170 len of test : 0
# train : [] test : [] i : 171 len of test : 0
# train : [] test : [] i : 172 len of test : 0
# train : [] test : [] i : 173 len of test : 0
# train : [] test : [] i : 174 len of test : 0
# train : [] test : [] i : 175 len of test : 0
# train : [] test : [] i : 176 len of test : 0
# train : [] test : [] i : 177 len of test : 0
# train : [] test : [] i : 178 len of test : 0
# train : [] test : [] i : 179 len of test : 0
# train : [] test : [] i : 180 len of test : 0
# train : [] test : [] i : 181 len of test : 0
# train : [] test : [] i : 182 len of test : 0
# train : [] test : [] i : 183 len of test : 0
# train : [] test : [] i : 184 len of test : 0
# train : [] test : [] i : 185 len of test : 0
# train : [] test : [] i : 186 len of test : 0
# train : [] test : [] i : 187 len of test : 0
# train : [] test : [] i : 188 len of test : 0
# train : [] test : [] i : 189 len of test : 0
# train : [] test : [] i : 190 len of test : 0
# train : [] test : [] i : 191 len of test : 0
# train : [] test : [] i : 192 len of test : 0
# train : [] test : [] i : 193 len of test : 0
# train : [] test : [] i : 194 len of test : 0
# train : [] test : [] i : 195 len of test : 0
# train : [] test : [] i : 196 len of test : 0
# train : [] test : [] i : 197 len of test : 0
# train : [] test : [] i : 198 len of test : 0
# train : [] test : [] i : 199 len of test : 0
# train : [] test : [] i : 200 len of test : 0
# train : [] test : [] i : 201 len of test : 0
# train : [] test : [] i : 202 len of test : 0
# train : [] test : [] i : 203 len of test : 0
# train : [] test : [] i : 204 len of test : 0
# train : [] test : [] i : 205 len of test : 0
# train : [] test : [] i : 206 len of test : 0
# train : [] test : [] i : 207 len of test : 0
# train : [] test : [] i : 208 len of test : 0
# train : [] test : [] i : 209 len of test : 0
# train : [] test : [] i : 210 len of test : 0
# train : [] test : [] i : 211 len of test : 0
# train : [] test : [] i : 212 len of test : 0
# train : [] test : [] i : 213 len of test : 0
# train : [] test : [] i : 214 len of test : 0
# train : [] test : [] i : 215 len of test : 0
# train : [] test : [] i : 216 len of test : 0
# train : [] test : [] i : 217 len of test : 0
# train : [] test : [] i : 218 len of test : 0
# train : [] test : [] i : 219 len of test : 0
# train : [] test : [] i : 220 len of test : 0
# train : [] test : [] i : 221 len of test : 0
# train : [] test : [] i : 222 len of test : 0
# train : [] test : [] i : 223 len of test : 0
# train : [] test : [] i : 224 len of test : 0
# train : [] test : [] i : 225 len of test : 0
# train : [] test : [] i : 226 len of test : 0
# train : [] test : [] i : 227 len of test : 0
# train : [] test : [] i : 228 len of test : 0
# train : [] test : [] i : 229 len of test : 0
# train : [] test : [] i : 230 len of test : 0
# train : [] test : [] i : 231 len of test : 0
# train : [] test : [] i : 232 len of test : 0
# train : [] test : [] i : 233 len of test : 0
# train : [] test : [] i : 234 len of test : 0
# train : [] test : [] i : 235 len of test : 0
# train : [] test : [] i : 236 len of test : 0
# train : [] test : [] i : 237 len of test : 0
# train : [] test : [] i : 238 len of test : 0
# train : [] test : [] i : 239 len of test : 0
# train : [] test : [] i : 240 len of test : 0
# train : [] test : [] i : 241 len of test : 0
# train : [] test : [] i : 242 len of test : 0
# train : [] test : [] i : 243 len of test : 0
# train : [] test : [] i : 244 len of test : 0
# train : [] test : [] i : 245 len of test : 0
# train : [] test : [] i : 246 len of test : 0
# train : [] test : [] i : 247 len of test : 0
# train : [] test : [] i : 248 len of test : 0
# train : [] test : [] i : 249 len of test : 0
# train : [] test : [] i : 250 len of test : 0
# train : [] test : [] i : 251 len of test : 0
# train : [] test : [] i : 252 len of test : 0
# train : [] test : [] i : 253 len of test : 0
# train : [] test : [] i : 254 len of test : 0
# train : [] test : [] i : 255 len of test : 0
# train : [] test : [] i : 256 len of test : 0
# train : [] test : [] i : 257 len of test : 0
# train : [] test : [] i : 258 len of test : 0
# train : [] test : [] i : 259 len of test : 0
# train : [] test : [] i : 260 len of test : 0
# train : [] test : [] i : 261 len of test : 0
# train : [] test : [] i : 262 len of test : 0
# train : [] test : [] i : 263 len of test : 0
# train : [] test : [] i : 264 len of test : 0
# train : [] test : [] i : 265 len of test : 0
# train : [] test : [] i : 266 len of test : 0
# train : [] test : [] i : 267 len of test : 0
# train : [] test : [] i : 268 len of test : 0
# train : [] test : [] i : 269 len of test : 0
# train : [] test : [] i : 270 len of test : 0
# train : [] test : [] i : 271 len of test : 0
# train : [] test : [] i : 272 len of test : 0
# train : [] test : [] i : 273 len of test : 0
# train : [] test : [] i : 274 len of test : 0
# train : [] test : [] i : 275 len of test : 0
# train : [] test : [] i : 276 len of test : 0
# train : [] test : [] i : 277 len of test : 0
# train : [] test : [] i : 278 len of test : 0
# train : [] test : [] i : 279 len of test : 0
# train : [] test : [] i : 280 len of test : 0
# train : [] test : [] i : 281 len of test : 0
# train : [] test : [] i : 282 len of test : 0
# train : [] test : [] i : 283 len of test : 0
# train : [] test : [] i : 284 len of test : 0
# train : [] test : [] i : 285 len of test : 0
# train : [] test : [] i : 286 len of test : 0
# train : [] test : [] i : 287 len of test : 0
# train : [] test : [] i : 288 len of test : 0
# train : [] test : [] i : 289 len of test : 0
# train : [] test : [] i : 290 len of test : 0
# train : [] test : [] i : 291 len of test : 0
# train : [] test : [] i : 292 len of test : 0
# train : [] test : [] i : 293 len of test : 0
# train : [] test : [] i : 294 len of test : 0
# train : [] test : [] i : 295 len of test : 0
# train : [] test : [] i : 296 len of test : 0
# train : [] test : [] i : 297 len of test : 0
# train : [] test : [] i : 298 len of test : 0
# train : [] test : [] i : 299 len of test : 0

# %%
padded_test_seq = np.pad(test_np[86+72:86+72+24],(0,(24-len(test_np[86+72:86+72+24]))),'constant',constant_values=0)

# %%
plt.plot(padded_test_seq)

# %%
len(padded_test_seq)
# Out:
# 24

# %%
plt.plot(test_np[86+72:86+72+24])

# %%
d_r['T'].iloc[6+86+72:6+86+72+24].plot()
# Out:
# <AxesSubplot:xlabel='Date_Time'>

# %%
len(test_np[86+72:86+72+24])
# Out:
# 10

# %%
np.sum(np.abs(padded_test_seq - d_r['T'].iloc[6+86+72:6+86+72+24].to_numpy())) # constant 0
# Out:
# 215.3

# %%
np.sum(np.abs(padded_test_seq - d_r['T'].iloc[6+86+72:6+86+72+24].to_numpy())) # edge
# Out:
# 53.89999999999999

# %%
np.sum(np.abs(padded_test_seq - d_r['T'].iloc[6+86+72:6+86+72+24].to_numpy())) #symmetric
# Out:
# 127.5

# %%
np.sum(np.abs(padded_test_seq - d_r['T'].iloc[6+86+72:6+86+72+24].to_numpy())) # reflect
# Out:
# 136.79999999999998

# %%
## Data processing

train_x_co = []
train_y_co = []
train_x_t = []
train_y_t = []

history = 72
horizon = 24

for i in range(len(train_data)-history):
    train_x_co_t = train_data['CO(GT)'].iloc[i:i+72].to_numpy()
    train_x_t_t = train_data['T'].iloc[i:i+72].to_numpy()
    train_y_co_t = train_data['CO(GT)'].iloc[i+72:i+72+24].to_numpy()
    if len(train_y_co_t) < 24 :
        print('[INFO] LENGTH IS LESS THAN 24')
        train_y_co_t = np.pad(train_y_co_t,(0,24-len(train_y_co_t)),'edge')
    train_y_t_t = train_data['T'].iloc[i+72:i+72+24].to_numpy()
    if len(train_y_t_t) < 24:
        train_y_t_t = np.pad(train_y_t_t,(0,24-len(train_y_t_t)),'edge')
        
    train_x_co.append(train_x_co_t)
    train_x_t.append(train_x_t_t)
    train_y_co.append(train_y_co_t)
    train_y_t.append(train_y_t_t)
# Out:
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24
# [INFO] LENGTH IS LESS THAN 24

# %%
len(train_x_co)
# Out:
# 96

# %%
len(train_y_co)
# Out:
# 96

# %%
train_y_co[-5:]
# Out:
# [array([7.6, 6.7, 5.7, 2.8, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6,
#         2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6]),
#  array([6.7, 5.7, 2.8, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6,
#         2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6]),
#  array([5.7, 2.8, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6,
#         2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6]),
#  array([2.8, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6,
#         2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6]),
#  array([2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6,
#         2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6, 2.6])]

# %% [markdown]
# generated numpy format of data but now using keras timeseries generators

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN, InputLayer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

seq_size = 72 # Number of time steps to look back 

batch_size = 1
train_generator = TimeseriesGenerator(train_data['CO(GT)'], train_data['CO(GT)'], length=seq_size, batch_size=batch_size)

# %%
print("Total number of samples in the original training data = ", len(train_data)) # 95
print("Total number of samples in the generated data = ", len(train_generator))
# Out:
# Total number of samples in the original training data =  168
# Total number of samples in the generated data =  96

# %%
################################################
#Input dimensions are... (N x seq_size)
print('Build feed forward NN model...')
# create and fit dense model
# model = tf.keras.Sequential()
model = (tf.keras.layers.Input(shape=(seq_size,1)))
model = (LSTM(128, activation='relu'))(model) #12
# model.add(tf.keras.layers.LSTMCell(50, activation='relu',input_shape = [72,1]))
model = (LSTM(128, activation='relu'))(model)  #8
model= (Dense(24))(model)
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['acc','mape'])
print(model.summary()) 

######################################################
# Out:
# Build feed forward NN model...
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-255-9337c73b6657> in <module>
#       5 # model = tf.keras.Sequential()
#       6 model = (tf.keras.layers.Input(shape=(seq_size,1)))
# ----> 7 model = (LSTM(128, activation='relu'))(model) #12
#       8 # model.add(tf.keras.layers.LSTMCell(50, activation='relu',input_shape = [72,1]))
#       9 model = (LSTM(128, activation='relu'))(model)  #8
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     666     additional_inputs = []
#     667     additional_specs = []
# --> 668     if initial_state is not None:
#     669       additional_inputs += initial_state
#     670       self.state_spec = nest.map_structure(
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     968         inputs, input_list, args, kwargs)
#     969     if self._expects_mask_arg and mask_is_implicit:
# --> 970       kwargs['mask'] = input_masks
#     971
#     972     # Training mode for `Layer.call` is set via (in order of priority):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1106
#    1107     # Only create Keras history if at least one tensor originates from a
# -> 1108     # `keras.Input`. Otherwise this Layer may be being used outside the Keras
#    1109     # framework.
#    1110     # TODO(kaftan): make this not special case inputs
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     838     # We enter a scratch graph and build placeholder inputs inside of it that
#     839     # match the input args.
# --> 840     # We then call the layer inside of the scratch graph to identify the
#     841     # output signatures, then we build KerasTensors corresponding to those
#     842     # outputs.
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     878
#     879   @generic_utils.default
# --> 880   def compute_mask(self, inputs, mask=None):  # pylint: disable=unused-argument
#     881     """Computes an output mask tensor.
#     882
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1151     # into the layer, it is padded and the row lengths are used for masking.
#    1152     inputs, row_lengths = K.convert_inputs_if_ragged(inputs)
# -> 1153     is_ragged_input = (row_lengths is not None)
#    1154     self._validate_args_if_ragged(is_ragged_input, mask)
#    1155
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in _process_inputs(self, inputs, initial_state, constants)
#     866
#     867   def _validate_args_if_ragged(self, is_ragged_input, mask):
# --> 868     if not is_ragged_input:
#     869       return
#     870
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in get_initial_state(self, inputs)
#     649       init_state = [init_state]
#     650     # Force the state to be a list in case it is a namedtuple eg LSTMStateTuple.
# --> 651     return list(init_state)
#     652
#     653   def __call__(self, inputs, initial_state=None, constants=None, **kwargs):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in get_initial_state(self, inputs, batch_size, dtype)
#    2515   well as the previous hidden state (which is what LSTMCell is limited to).
#    2516   This allows PeepholeLSTMCell to better learn precise timings over LSTMCell.
# -> 2517
#    2518   From [Gers et al., 2002](
#    2519     http://www.jmlr.org/papers/volume3/gers02a/gers02a.pdf):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in _generate_zero_filled_state_for_cell(cell, inputs, batch_size, dtype)
#    2996
#    2997   def create_zeros(unnested_state_size):
# -> 2998     flat_dims = tensor_shape.TensorShape(unnested_state_size).as_list()
#    2999     init_state_size = [batch_size_tensor] + flat_dims
#    3000     return array_ops.zeros(init_state_size, dtype=dtype)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in _generate_zero_filled_state(batch_size_tensor, state_size, dtype)
#    3012   device as the training worker. By enabling the device cache, this allows
#    3013   worker to read the variable once and cache locally, rather than read it every
# -> 3014   time step from remote when it is needed.
#    3015
#    3016   Note that this is assuming the variable that cell needs for each time step is
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865         raise ValueError(
#     866             "Incompatible CompositeTensor TypeSpecs: %s vs. %s -- %s" %
# --> 867             (type_spec_1, type_spec_2, e))
#     868
#     869     elif _is_type_spec(shallow_tree):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865         raise ValueError(
#     866             "Incompatible CompositeTensor TypeSpecs: %s vs. %s -- %s" %
# --> 867             (type_spec_1, type_spec_2, e))
#     868
#     869     elif _is_type_spec(shallow_tree):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in create_zeros(unnested_state_size)
#    3009   """Returns the caching device for the RNN variable.
#    3010
# -> 3011   This is useful for distributed training, when variable is not located as same
#    3012   device as the training worker. By enabling the device cache, this allows
#    3013   worker to read the variable once and cache locally, rather than read it every
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204       # TypeError, when given unexpected types.  So we need to catch both.
#     205       result = dispatch(wrapper, args, kwargs)
# --> 206       if result is not OpDispatcher.NOT_SUPPORTED:
#     207         return result
#     208       else:
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in wrapped(*args, **kwargs)
#    2909   Args:
#    2910     tensor: A `Tensor`.
# -> 2911     dtype: A type for the returned `Tensor`. Must be `float16`, `float32`,
#    2912       `float64`, `int8`, `uint8`, `int16`, `uint16`, `int32`, `int64`,
#    2913       `complex64`, `complex128`, `bool` or `string`. (optional)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in zeros(shape, dtype, name)
#    2958     dtype: A type for the returned `Tensor`. Must be `float16`, `float32`,
#    2959       `float64`, `int8`, `uint8`, `int16`, `uint16`, `int32`, `int64`,
# -> 2960       `complex64`, `complex128`, `bool` or `string` (optional).
#    2961     name: A name for the operation (optional).
#    2962
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in _constant_if_small(value, shape, dtype, name)
#    2894   you can use `dtype` to specify a new type for the returned tensor.
#    2895
# -> 2896   Examples:
#    2897
#    2898     >>> tensor = tf.constant([[1, 2, 3], [4, 5, 6]])
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    3050     array([1, 2, 6])
#    3051     >>> a = np.array([[1, 2, 3], [4, 5, 6]])
# -> 3052     >>> np.cumprod(a, dtype=float) # specify type of output
#    3053     array([   1.,    2.,    6.,   24.,  120.,  720.])
#    3054
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84             else:
#      85                 return reduction(axis=axis, out=out, **passkwargs)
# ---> 86
#      87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in __array__(self)
#     868     """Dummy method to prevent a tensor from being used as a Python `bool`.
#     869
# --> 870     This overload raises a `TypeError` when the user inadvertently
#     871     treats a `Tensor` as a boolean (most commonly in an `if` or `while`
#     872     statement), in code that was not converted by AutoGraph. For example:
#
# NotImplementedError: Cannot convert a symbolic Tensor (lstm_30/strided_slice:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported

# %%
for i in train_y_co:
    assert len(i) == 24

# %%
train_x_co = np.array(train_x_co)

# %%
train_x_co.shape
# Out:
# (96, 72)

# %%
train_y_co = np.array(train_y_co)
train_y_co.shape
# Out:
# (96, 24)

# %%
model.fit(x=train_x_co.reshape(-1,72,1),y=train_y_co.reshape(-1,24,1), verbose=2, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f8a8053f8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f8a8053f8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     431       raise
# --> 432     return _fall_back_unconverted(f, args, kwargs, options, e)
#     433
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _convert_actual(entity, program_ctx)
#     273
# --> 274
#     275 def _convert_actual(entity, program_ctx):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform(self, obj, user_context)
#     285     if inspect.isfunction(obj) or inspect.ismethod(obj):
# --> 286       return self.transform_function(obj, user_context)
#     287
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform_function(self, fn, user_context)
#     497         defaults=fn.__defaults__,
# --> 498         kwdefaults=getattr(fn, '__kwdefaults__', None))
#     499     return transformed_fn, factory.module, factory.source_map
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/transpiler.py in instantiate(self, globals_, closure, defaults, kwdefaults)
#     206           'closure mismatch, requested {}, but source function had {}'.format(
# --> 207               self._freevars, factory_freevars))
#     208
#
# ValueError: closure mismatch, requested ('self', 'step_function'), but source function had ()
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-253-a82e086d2e6a> in <module>
# ----> 1 model.fit(x=train_x_co.reshape(-1,72,1),y=train_y_co.reshape(-1,24,1), verbose=2, epochs=100)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181     x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
#    1182
# -> 1183     y_pred = self(x, training=False)
#    1184     # Updates stateful loss metrics.
#    1185     self.compiled_loss(
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887         # stateless function.
#     888         return self._stateless_fn(*args, **kwds)
# --> 889     else:
#     890       _, _, _, filtered_flat_args = \
#     891           self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931               "def f():\n"
#     932               "  return v\n"
# --> 933               "\n"
#     934               "f()  # <tf.Tensor: numpy=1.>\n"
#     935               "v.assign_add(1.)\n"
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     762
#     763     We use this in tf.Module to allow user annotated `tf.functions` to remain as
# --> 764     `Function` objects but still automatically enter the Module name_scope
#     765     when they are evaluated like all other methods.
#     766
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       *args: inputs to specialize on.
#    3049       **kwargs: inputs to specialize on.
# -> 3050     """
#    3051     graph_function = self._get_concrete_function_garbage_collected(
#    3052         *args, **kwargs)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443   ```python
# -> 3444   import tensorflow as tf
#    3445
#    3446   tf.compat.v1.enable_eager_execution()
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3287     ])
#    3288
# -> 3289   def _maybe_define_function(self, args, kwargs):
#    3290     """Gets a function for these inputs, defining it if necessary.
#    3291
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997       check_mutation(func_args_before, func_args, original_func)
#     998       check_mutation(func_kwargs_before, func_kwargs, original_func)
# --> 999     finally:
#    1000       current_scope.set_use_resource(default_use_recource)
#    1001
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670       attributes = self._create_implements_attribute()
#     671
# --> 672     share = self._shared_rendezvous
#     673     if share is not None:
#     674       attributes[function_lib.SHARED_RENDEZVOUS_ATTRIBUTE_NAME] = share
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     980
#     981         # Wrapping around a decorator allows checks like tf_inspect.getargspec
# --> 982         # to be accurate.
#     983         converted_func = tf_decorator.make_decorator(original_func, wrapper)
#     984         python_func = tf_decorator.rewrap(python_func, original_func,
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     return _call_unconverted(f, args, kwargs, options)
#     438   elif (hasattr(target_entity.__code__, 'co_filename') and
# --> 439         target_entity.__code__.co_filename == '<string>'):
#     440     # TODO(mdan): __globals__['txt'] might work in Py3.
#     441     logging.log(2, 'Permanently allowed: %s: dynamic code (exec?)',
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _fall_back_unconverted(f, args, kwargs, options, exc)
#     484   # TODO(mdan): Consider adding an internal metric.
#     485   warning_template = (
# --> 486       'AutoGraph could not transform %s and will run it as-is.\n'
#     487       '%s'
#     488       'Cause: %s\n'
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461         result = converted_f(*effective_args)
#     462     except Exception as e:
# --> 463       _attach_error_metadata(e, converted_f)
#     464       raise
#     465
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_function(iterator)
#     853             of either `(inputs, targets)` or
#     854             `(inputs, targets, sample_weights)`.
# --> 855           - A generator or `keras.utils.Sequence` returning `(inputs, targets)`
#     856             or `(inputs, targets, sample_weights)`.
#     857           A more detailed description of unpacking behavior for iterator types
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in step_function(model, iterator)
#     843
#     844     Arguments:
# --> 845         x: Input data. It could be:
#     846           - A Numpy array (or array-like), or a list of arrays
#     847             (in case the model has multiple inputs).
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1283     per_replica_result = strategy.run(step_fn)
#    1284     # Check devices on which per replica result is:
# -> 1285     strategy.experimental_local_results(per_replica_result)[0].device
#    1286     # /job:localhost/replica:0/task:0/device:GPU:0
#    1287     strategy.experimental_local_results(per_replica_result)[1].device
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2831 #   call (except during a `merge_run` call) and in such a scope it
#    2832 #   will be returned by calls to `get_replica_context()`.  Implementers of new
# -> 2833 #   Strategy descendants will frequently also need to
#    2834 #   define a descendant of ReplicaContext, and are responsible for
#    2835 #   entering and exiting this context.
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     690   Unlike `tf.function`, `to_graph` is a low-level transpiler that converts
#     691   Python code to TensorFlow graph code. It does not implement any caching,
# --> 692   variable management or create any actual ops, and is best used where greater
#     693   control over the generated TensorFlow graph is desired. Another difference
#     694   from `tf.function` is that `to_graph` will not wrap the graph into a
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380       return py_builtins.eval_in_original_context(f, args, caller_fn_scope)
#     381     if f is super:
# --> 382       return py_builtins.super_in_original_context(f, args, caller_fn_scope)
#     383     if f is globals:
#     384       return py_builtins.globals_in_original_context(caller_fn_scope)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461         result = converted_f(*effective_args)
#     462     except Exception as e:
# --> 463       _attach_error_metadata(e, converted_f)
#     464       raise
#     465
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in run_step(data)
#     836           validation_steps=None,
#     837           validation_batch_size=None,
# --> 838           validation_freq=1,
#     839           max_queue_size=10,
#     840           workers=1,
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_step(self, data)
#     793
#     794       data = next(iterator)
# --> 795       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     796       outputs = reduce_per_replica(
#     797           outputs, self.distribute_strategy, reduction='first')
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1028         np_arrays.ndarray, np.ndarray, float, int)) for x in input_list):
#    1029
# -> 1030       def _convert_non_tensor(x):
#    1031         # Don't call `ops.convert_to_tensor` on all `inputs` because
#    1032         # `SparseTensors` can't be converted to `Tensor`.
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     392         raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#     393       # `outputs` will be the inputs to the next layer.
# --> 394       inputs = outputs
#     395       mask = getattr(outputs, '_keras_mask', None)
#     396     return outputs
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     666     additional_inputs = []
#     667     additional_specs = []
# --> 668     if initial_state is not None:
#     669       additional_inputs += initial_state
#     670       self.state_spec = nest.map_structure(
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1028         np_arrays.ndarray, np.ndarray, float, int)) for x in input_list):
#    1029
# -> 1030       def _convert_non_tensor(x):
#    1031         # Don't call `ops.convert_to_tensor` on all `inputs` because
#    1032         # `SparseTensors` can't be converted to `Tensor`.
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1151     # into the layer, it is padded and the row lengths are used for masking.
#    1152     inputs, row_lengths = K.convert_inputs_if_ragged(inputs)
# -> 1153     is_ragged_input = (row_lengths is not None)
#    1154     self._validate_args_if_ragged(is_ragged_input, mask)
#    1155
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in _process_inputs(self, inputs, initial_state, constants)
#     866
#     867   def _validate_args_if_ragged(self, is_ragged_input, mask):
# --> 868     if not is_ragged_input:
#     869       return
#     870
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in get_initial_state(self, inputs)
#     649       init_state = [init_state]
#     650     # Force the state to be a list in case it is a namedtuple eg LSTMStateTuple.
# --> 651     return list(init_state)
#     652
#     653   def __call__(self, inputs, initial_state=None, constants=None, **kwargs):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in get_initial_state(self, inputs, batch_size, dtype)
#    2515   well as the previous hidden state (which is what LSTMCell is limited to).
#    2516   This allows PeepholeLSTMCell to better learn precise timings over LSTMCell.
# -> 2517
#    2518   From [Gers et al., 2002](
#    2519     http://www.jmlr.org/papers/volume3/gers02a/gers02a.pdf):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in _generate_zero_filled_state_for_cell(cell, inputs, batch_size, dtype)
#    2996
#    2997   def create_zeros(unnested_state_size):
# -> 2998     flat_dims = tensor_shape.TensorShape(unnested_state_size).as_list()
#    2999     init_state_size = [batch_size_tensor] + flat_dims
#    3000     return array_ops.zeros(init_state_size, dtype=dtype)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in _generate_zero_filled_state(batch_size_tensor, state_size, dtype)
#    3012   device as the training worker. By enabling the device cache, this allows
#    3013   worker to read the variable once and cache locally, rather than read it every
# -> 3014   time step from remote when it is needed.
#    3015
#    3016   Note that this is assuming the variable that cell needs for each time step is
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865         raise ValueError(
#     866             "Incompatible CompositeTensor TypeSpecs: %s vs. %s -- %s" %
# --> 867             (type_spec_1, type_spec_2, e))
#     868
#     869     elif _is_type_spec(shallow_tree):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865         raise ValueError(
#     866             "Incompatible CompositeTensor TypeSpecs: %s vs. %s -- %s" %
# --> 867             (type_spec_1, type_spec_2, e))
#     868
#     869     elif _is_type_spec(shallow_tree):
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py in create_zeros(unnested_state_size)
#    3009   """Returns the caching device for the RNN variable.
#    3010
# -> 3011   This is useful for distributed training, when variable is not located as same
#    3012   device as the training worker. By enabling the device cache, this allows
#    3013   worker to read the variable once and cache locally, rather than read it every
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204       # TypeError, when given unexpected types.  So we need to catch both.
#     205       result = dispatch(wrapper, args, kwargs)
# --> 206       if result is not OpDispatcher.NOT_SUPPORTED:
#     207         return result
#     208       else:
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in wrapped(*args, **kwargs)
#    2909   Args:
#    2910     tensor: A `Tensor`.
# -> 2911     dtype: A type for the returned `Tensor`. Must be `float16`, `float32`,
#    2912       `float64`, `int8`, `uint8`, `int16`, `uint16`, `int32`, `int64`,
#    2913       `complex64`, `complex128`, `bool` or `string`. (optional)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in zeros(shape, dtype, name)
#    2958     dtype: A type for the returned `Tensor`. Must be `float16`, `float32`,
#    2959       `float64`, `int8`, `uint8`, `int16`, `uint16`, `int32`, `int64`,
# -> 2960       `complex64`, `complex128`, `bool` or `string` (optional).
#    2961     name: A name for the operation (optional).
#    2962
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in _constant_if_small(value, shape, dtype, name)
#    2894   you can use `dtype` to specify a new type for the returned tensor.
#    2895
# -> 2896   Examples:
#    2897
#    2898     >>> tensor = tf.constant([[1, 2, 3], [4, 5, 6]])
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    3050     array([1, 2, 6])
#    3051     >>> a = np.array([[1, 2, 3], [4, 5, 6]])
# -> 3052     >>> np.cumprod(a, dtype=float) # specify type of output
#    3053     array([   1.,    2.,    6.,   24.,  120.,  720.])
#    3054
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84             else:
#      85                 return reduction(axis=axis, out=out, **passkwargs)
# ---> 86
#      87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#
# ~/opt/anaconda3/envs/hack/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in __array__(self)
#     868     """Dummy method to prevent a tensor from being used as a Python `bool`.
#     869
# --> 870     This overload raises a `TypeError` when the user inadvertently
#     871     treats a `Tensor` as a boolean (most commonly in an `if` or `while`
#     872     statement), in code that was not converted by AutoGraph. For example:
#
# NotImplementedError: Cannot convert a symbolic Tensor (sequential_17/lstm_27/strided_slice:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported

# %%
del model

# %%
preds = model.predict(train_x_co)

# %%
preds[:5]
# Out:
# array([[2.078202  , 1.8687559 , 2.1188428 , 1.9616783 , 1.4741291 ,
#         1.4418817 , 1.0409621 , 0.9110356 , 2.4735255 , 2.8756568 ,
#         3.0357761 , 2.5286775 , 1.942743  , 2.2712648 , 2.1987617 ,
#         2.1389642 , 2.819009  , 3.1855183 , 3.4505062 , 5.238379  ,
#         5.5649285 , 3.4462893 , 2.590944  , 2.0384395 ],
#        [2.2873924 , 1.8146963 , 2.3572414 , 2.0673988 , 0.99127257,
#         0.33167803, 1.3169961 , 1.8902313 , 2.9511356 , 2.9326336 ,
#         2.7204678 , 2.3017728 , 1.9947876 , 1.6786721 , 1.7018765 ,
#         2.133882  , 2.5847094 , 4.020931  , 5.6675143 , 5.666073  ,
#         3.8083818 , 2.3628342 , 2.0609076 , 1.8977785 ],
#        [2.1631176 , 1.6347924 , 1.8252277 , 1.2364169 , 0.49866322,
#         0.6613692 , 2.3911602 , 2.8536415 , 2.9423118 , 2.8094642 ,
#         3.2327085 , 2.7215288 , 2.535184  , 1.9981896 , 2.0637743 ,
#         2.6208665 , 3.6744843 , 5.172644  , 5.690958  , 4.031865  ,
#         2.656418  , 2.0984614 , 2.1693661 , 2.027152  ],
#        [2.168191  , 1.8512844 , 1.2068704 , 0.8535497 , 1.1256964 ,
#         2.1760004 , 2.8446453 , 2.9075048 , 2.6930394 , 2.4402356 ,
#         2.3609073 , 2.4653978 , 2.0042427 , 1.861962  , 2.3217826 ,
#         3.4107966 , 5.1435256 , 5.7077775 , 4.163376  , 2.5024498 ,
#         2.6480718 , 1.9924904 , 2.2659526 , 1.7214636 ],
#        [2.4714396 , 1.2827245 , 0.6487205 , 1.3316095 , 2.2394643 ,
#         2.31994   , 2.833334  , 2.4207535 , 2.5250807 , 2.244978  ,
#         2.393831  , 2.1290522 , 2.8108377 , 2.8895607 , 3.4729486 ,
#         4.867343  , 4.977466  , 3.4574962 , 2.8324096 , 2.337506  ,
#         1.9952276 , 1.8475671 , 2.0063624 , 1.26305   ]], dtype=float32)

# %%
train_y_co[:5]
# Out:
# array([[2.9, 2.8, 2.5, 2.4, 2.4, 1.2, 1. , 0.9, 1.4, 1.6, 2.2, 2.8, 2.8,
#         2. , 1.8, 1.9, 3. , 2.9, 2.5, 4.6, 5.9, 3.4, 2.1, 2.2],
#        [2.8, 2.5, 2.4, 2.4, 1.2, 1. , 0.9, 1.4, 1.6, 2.2, 2.8, 2.8, 2. ,
#         1.8, 1.9, 3. , 2.9, 2.5, 4.6, 5.9, 3.4, 2.1, 2.2, 1.8],
#        [2.5, 2.4, 2.4, 1.2, 1. , 0.9, 1.4, 1.6, 2.2, 2.8, 2.8, 2. , 1.8,
#         1.9, 3. , 2.9, 2.5, 4.6, 5.9, 3.4, 2.1, 2.2, 1.8, 1.8],
#        [2.4, 2.4, 1.2, 1. , 0.9, 1.4, 1.6, 2.2, 2.8, 2.8, 2. , 1.8, 1.9,
#         3. , 2.9, 2.5, 4.6, 5.9, 3.4, 2.1, 2.2, 1.8, 1.8, 1.8],
#        [2.4, 1.2, 1. , 0.9, 1.4, 1.6, 2.2, 2.8, 2.8, 2. , 1.8, 1.9, 3. ,
#         2.9, 2.5, 4.6, 5.9, 3.4, 2.1, 2.2, 1.8, 1.8, 1.8, 1.1]])

# %%
next_pred = model.predict(train_data['CO(GT)'].iloc[-72:].to_numpy().reshape(1,-1))

# %%
plt.plot(next_pred.squeeze())

# %%
test_data['CO(GT)'].iloc[:24].plot()
# Out:
# <AxesSubplot:xlabel='Date_Time'>

# %%
print(f"MAPE : {mean_absolute_percentage_error(next_pred.squeeze(),test_data['CO(GT)'].iloc[:24])}")
# Out:
# MAPE : 0.28707065370224044

# %%
d_r.iloc[5*24+6]
# Out:
# CO(GT)              2.1000
# PT08.S1(CO)      1304.0000
# NMHC(GT)          155.0000
# C6H6(GT)           11.1000
# PT08.S2(NMHC)    1019.0000
# NOx(GT)           127.0000
# PT08.S3(NOx)      852.0000
# NO2(GT)           103.0000
# PT08.S4(NO2)     1731.0000
# PT08.S5(O3)      1272.0000
# T                  14.1000
# RH                 65.7000
# AH                  1.0494
# Name: 2004-03-16 00:00:00, dtype: float64

# %%
test_set = []
for i in range(5,11):
    test_set.append(d_r['CO(GT)'].iloc[i*24+6:(i+3)*24+6].to_numpy())

# %%
test_set[0]
# Out:
# array([2.1, 1.2, 0.8, 0.7, 0.7, 0.6, 0.9, 1.3, 3.4, 3.7, 5.3, 4.1, 3.3,
#        4. , 3.8, 2.8, 2.9, 2.9, 3.4, 3.9, 3.2, 5.1, 2.6, 1.7, 1.7, 1.2,
#        0.9, 0.7, 0.7, 0.5, 0.5, 1.6, 4.1, 6.6, 4.3, 2.9, 2.5, 2.8, 2.6,
#        2. , 2.9, 2.5, 5. , 7.6, 6.7, 5.7, 2.8, 2.6, 2.3, 1.4, 1. , 0.7,
#        0.7, 0.6, 0.7, 1.5, 4.7, 6.6, 4.5, 2.8, 2.2, 2.2, 2.3, 2.2, 2.8,
#        2.7, 3.7, 5.1, 5.1, 3.2, 2.1, 1.7])

# %%
test_set_preds = model.predict(np.array(test_set))

# %%
for i,pred in enumerate(test_set_preds):
    print(f"{i}) MAPE : {mean_absolute_percentage_error(pred,d_r['CO(GT)'].iloc[(8+i)*24+6:(9+i)*24+6].to_numpy())} ")
# Out:
# 0) MAPE : 0.7304592547646411
# 1) MAPE : 0.34917515896177315
# 2) MAPE : 0.4136497674314638
# 3) MAPE : 0.4275968213707075
# 4) MAPE : 0.2892885992198683
# 5) MAPE : 0.24180267045573325

# %%
i = 0
d_r['CO(GT)'].iloc[(8+i)*24+6:(9+i)*24+6]
# Out:
# Date_Time
# 2004-03-19 00:00:00    2.0
# 2004-03-19 01:00:00    1.6
# 2004-03-19 02:00:00    0.9
# 2004-03-19 03:00:00    0.7
# 2004-03-19 04:00:00    0.7
# 2004-03-19 05:00:00    0.5
# 2004-03-19 06:00:00    0.7
# 2004-03-19 07:00:00    1.5
# 2004-03-19 08:00:00    4.8
# 2004-03-19 09:00:00    6.2
# 2004-03-19 10:00:00    4.0
# 2004-03-19 11:00:00    3.3
# 2004-03-19 12:00:00    2.8
# 2004-03-19 13:00:00    3.0
# 2004-03-19 14:00:00    3.3
# 2004-03-19 15:00:00    3.5
# 2004-03-19 16:00:00    4.0
# 2004-03-19 17:00:00    4.6
# 2004-03-19 18:00:00    4.1
# 2004-03-19 19:00:00    4.5
# 2004-03-19 20:00:00    3.9
# 2004-03-19 21:00:00    4.0
# 2004-03-19 22:00:00    2.2
# 2004-03-19 23:00:00    2.1
# Name: CO(GT), dtype: float64

# %%
t = list(test_set_preds[0])
for i in range(1,len(test_set_preds)):
    t= t+list(test_set_preds[i])

# %%
t_backup = t

# %%
plt.plot(t)

# %%
test_data['CO(GT)'].iloc[24:].plot()
# Out:
# <AxesSubplot:xlabel='Date_Time'>

# %%
t = list(next_pred.squeeze()) + t
print(len(t))
# Out:
# 168

# %%
print(f"MAPE : {mean_absolute_percentage_error(t,test_data['CO(GT)'])}")
# Out:
# MAPE : 0.39129184655806104

# %%
model.save('DNN_MAPE_0_3912.h5')

# %%
test_model = keras.models.load_model('DNN_MAPE_0_3912.h5') # working

# %% [markdown]
# ```python
# import pickle
#
# file_name = 'DNN_MAPE_0.3912.pkl'
# pickle.dump(model,open(file_name,'w'))
# ```

# %% [markdown]
# ```python>>> import calendar
# >>> import datetime as dt
# >>> import math
# >>> from river import compose
# >>> from river import datasets
# >>> from river import linear_model
# >>> from river import metrics
# >>> from river import optim
# >>> from river import preprocessing
# >>> from river import time_series
#
# >>> def get_month_distances(x):
# ...     return {
# ...         calendar.month_name[month]: math.exp(-(x['month'].month - month) ** 2)
# ...         for month in range(1, 13)
# ...     }
#
# >>> def get_ordinal_date(x):
# ...     return {'ordinal_date': x['month'].toordinal()}
#
# >>> extract_features = compose.TransformerUnion(
# ...     get_ordinal_date,
# ...     get_month_distances
# ... )
#
# >>> model = (
# ...     extract_features |
# ...     time_series.SNARIMAX(
# ...         p=0,
# ...         d=0,
# ...         q=0,
# ...         m=12,
# ...         sp=3,
# ...         sq=6,
# ...         regressor=(
# ...             preprocessing.StandardScaler() |
# ...             linear_model.LinearRegression(
# ...                 intercept_init=110,
# ...                 optimizer=optim.SGD(0.01),
# ...                 intercept_lr=0.3
# ...             )
# ...         )
# ...     )
# ... )
#
# >>> metric = metrics.Rolling(metrics.MAE(), 12)
#
# >>> for x, y in datasets.AirlinePassengers():
# ...     y_pred = model.forecast(horizon=1, xs=[x])
# ...     model = model.learn_one(x, y)
# ...     metric = metric.update(y, y_pred[0])
#
# >>> metric
# MAE: 11.636563  (rolling 12)
#
# >>> horizon = 12
# >>> future = [
# ...     {'month': dt.date(year=1961, month=m, day=1)}
# ...     for m in range(1, horizon + 1)
# ... ]
# >>> forecast = model.forecast(horizon=horizon, xs=future)
# >>> for x, y_pred in zip(future, forecast):
# ...     print(x['month'], f'{y_pred:.3f}')
# 1961-01-01 442.554
# 1961-02-01 427.305
# 1961-03-01 471.861
# 1961-04-01 483.978
# 1961-05-01 489.995
# 1961-06-01 544.270
# 1961-07-01 632.882
# 1961-08-01 633.229
# 1961-09-01 531.349
# 1961-10-01 457.258
# 1961-11-01 405.978
# 1961-12-01 439.674
# ```

# %%
# !pip install -U tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (2.5.0)
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp37-cp37m-macosx_10_11_x86_64.whl (207.0 MB)
#      |████████████████████████████████| 207.0 MB 52 kB/s eta 0:00:014
# Requirement already satisfied: astunparse>=1.6.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (3.7.4.3)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 592 kB/s eta 0:00:01
# Requirement already satisfied: protobuf>=3.9.2 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (3.15.8)
# Requirement already satisfied: h5py>=2.9.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.12)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 846 kB/s eta 0:00:01
# Collecting libclang>=9.0.1
#   Downloading libclang-13.0.0-py2.py3-none-macosx_10_9_x86_64.whl (13.0 MB)
#      |████████████████████████████████| 13.0 MB 1.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.21.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (0.13.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorflow) (1.15.0)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 97 kB/s eta 0:00:012
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.23.1-cp37-cp37m-macosx_10_14_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 98 kB/s eta 0:00:013
# Requirement already satisfied: cached-property in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.0.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/kishorekunisetty/opt/anaconda3/envs/hack/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.4.1)
# Installing collected packages: tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, libclang, keras, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# Successfully installed keras-2.7.0 libclang-13.0.0 tensorboard-2.8.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.23.1
